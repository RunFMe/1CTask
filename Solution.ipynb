# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, log_loss
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostClassifier, Pool
from sklearn.calibration import calibration_curve
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv('./fake_job_postings.csv')

# %%
data
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# 2             US, IA, Wever          NaN          NaN
# 3        US, DC, Washington        Sales          NaN
# 4        US, FL, Fort Worth          NaN          NaN
# ...                     ...          ...          ...
# 17875       CA, ON, Toronto        Sales          NaN
# 17876  US, PA, Philadelphia   Accounting          NaN
# 17877       US, TX, Houston          NaN          NaN
# 17878         NG, LA, Lagos          NaN          NaN
# 17879     NZ, N, Wellington  Engineering          NaN
#
#                                          company_profile  \
# 0      We're Food52, and we've created a groundbreaki...
# 1      90 Seconds, the worlds Cloud Video Production ...
# 2      Valor Services provides Workforce Solutions th...
# 3      Our passion for improving quality of life thro...
# 4      SpotSource Solutions LLC is a Global Human Cap...
# ...                                                  ...
# 17875  Vend is looking for some awesome new talent to...
# 17876  WebLinc is the e-commerce platform and service...
# 17877  We Provide Full Time Permanent Positions for m...
# 17878                                                NaN
# 17879  Vend is looking for some awesome new talent to...
#
#                                              description  \
# 0      Food52, a fast-growing, James Beard Award-winn...
# 1      Organised - Focused - Vibrant - Awesome!Do you...
# 2      Our client, located in Houston, is actively se...
# 3      THE COMPANY: ESRI – Environmental Systems Rese...
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...
# ...                                                  ...
# 17875  Just in case this is the first time you’ve vis...
# 17876  The Payroll Accountant will focus primarily on...
# 17877  Experienced Project Cost Control Staff Enginee...
# 17878  Nemsia Studios is looking for an experienced v...
# 17879  Who are we?Vend is an award winning web based ...
#
#                                             requirements  \
# 0      Experience with content management systems a m...
# 1      What we expect from you:Your key responsibilit...
# 2      Implement pre-commissioning and commissioning ...
# 3      EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4      QUALIFICATIONS:RN license in the State of Texa...
# ...                                                  ...
# 17875  To ace this role you:Will eat comprehensive St...
# 17876  - B.A. or B.S. in Accounting- Desire to have f...
# 17877  At least 12 years professional experience.Abil...
# 17878  1. Must be fluent in the latest versions of Co...
# 17879  We want to hear from you if:You have an in-dep...
#
#                                                 benefits  telecommuting  \
# 0                                                    NaN              0
# 1      What you will get from usThrough being part of...              0
# 2                                                    NaN              0
# 3      Our culture is anything but corporate—we have ...              0
# 4                                  Full Benefits Offered              0
# ...                                                  ...            ...
# 17875  What can you expect from us?We have an open cu...              0
# 17876  Health &amp; WellnessMedical planPrescription ...              0
# 17877                                                NaN              0
# 17878  Competitive salary (compensation will be based...              0
# 17879                                                NaN              0
#
#        has_company_logo  has_questions employment_type required_experience  \
# 0                     1              0           Other          Internship
# 1                     1              0       Full-time      Not Applicable
# 2                     1              0             NaN                 NaN
# 3                     1              0       Full-time    Mid-Senior level
# 4                     1              1       Full-time    Mid-Senior level
# ...                 ...            ...             ...                 ...
# 17875                 1              1       Full-time    Mid-Senior level
# 17876                 1              1       Full-time    Mid-Senior level
# 17877                 0              0       Full-time                 NaN
# 17878                 0              1        Contract      Not Applicable
# 17879                 1              1       Full-time    Mid-Senior level
#
#       required_education                   industry              function  \
# 0                    NaN                        NaN             Marketing
# 1                    NaN  Marketing and Advertising      Customer Service
# 2                    NaN                        NaN                   NaN
# 3      Bachelor's Degree          Computer Software                 Sales
# 4      Bachelor's Degree     Hospital & Health Care  Health Care Provider
# ...                  ...                        ...                   ...
# 17875                NaN          Computer Software                 Sales
# 17876  Bachelor's Degree                   Internet   Accounting/Auditing
# 17877                NaN                        NaN                   NaN
# 17878       Professional             Graphic Design                Design
# 17879                NaN          Computer Software           Engineering
#
#        fraudulent
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 17875           0
# 17876           0
# 17877           0
# 17878           0
# 17879           0
#
# [17880 rows x 18 columns]

# %%
data.isna().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %% [markdown]
# Обработаем колонку salary_range

# %%
data['salary_range'][~data['salary_range'].isna()]
# Out:
# 6          20000-28000
# 10       100000-120000
# 15       120000-150000
# 23       100000-120000
# 31         50000-65000
#              ...
# 17844              0-0
# 17849     80000-100000
# 17865      18000-20000
# 17867      18000-19000
# 17874     80000-100000
# Name: salary_range, Length: 2868, dtype: object

# %% [markdown]
# В данных бывают зарплаты 0-0, скорее всего это значит, что работа бесплатная.

# %%
def get_salary_bound_aggregator(aggregator, error_value=np.nan):
    def get_bounds_aggregated(salary_range):
        if pd.isnull(salary_range):
            return np.nan
        # check if salary_range has format 'low'-'max'
        if not '-' in salary_range:
            bounds = [salary_range, salary_range]
        else:
            bounds = salary_range.split('-')
            assert len(bounds) == 2, f"salary_range={salary_range} is not formatted"
        
        # Try converting bounds to ints
        try:
            bounds = list(map(int, bounds))
        except ValueError:
            print(f'{salary_range} does not contain integers. Substituted both bounds with NaN')
            bounds = [np.nan, np.nan]
        return aggregator(bounds)
        
    return get_bounds_aggregated

# %%
data['min_salary'] = data['salary_range'].apply(get_salary_bound_aggregator(min))
data['max_salary'] = data['salary_range'].apply(get_salary_bound_aggregator(max))
data.drop(columns='salary_range', inplace=True)
# Out:
# 9-Dec does not contain integers. Substituted both bounds with NaN
# 3-Apr does not contain integers. Substituted both bounds with NaN
# 4-Apr does not contain integers. Substituted both bounds with NaN
# Oct-15 does not contain integers. Substituted both bounds with NaN
# 8-Sep does not contain integers. Substituted both bounds with NaN
# 4-Jun does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# Oct-20 does not contain integers. Substituted both bounds with NaN
# Jun-18 does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 11-Nov does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 11-Dec does not contain integers. Substituted both bounds with NaN
# 2-Apr does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 11-Nov does not contain integers. Substituted both bounds with NaN
# 2-Jun does not contain integers. Substituted both bounds with NaN
# Oct-20 does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# Dec-25 does not contain integers. Substituted both bounds with NaN
# 9-Dec does not contain integers. Substituted both bounds with NaN
# 3-Apr does not contain integers. Substituted both bounds with NaN
# 4-Apr does not contain integers. Substituted both bounds with NaN
# Oct-15 does not contain integers. Substituted both bounds with NaN
# 8-Sep does not contain integers. Substituted both bounds with NaN
# 4-Jun does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# Oct-20 does not contain integers. Substituted both bounds with NaN
# Jun-18 does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 11-Nov does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 11-Dec does not contain integers. Substituted both bounds with NaN
# 2-Apr does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 11-Nov does not contain integers. Substituted both bounds with NaN
# 2-Jun does not contain integers. Substituted both bounds with NaN
# Oct-20 does not contain integers. Substituted both bounds with NaN
# 10-Oct does not contain integers. Substituted both bounds with NaN
# 10-Nov does not contain integers. Substituted both bounds with NaN
# Dec-25 does not contain integers. Substituted both bounds with NaN

# %% [markdown]
# Теперь разобьем все фичи на типы. Их нужно будет обрабатывать по-разному.

# %%
num_features = [
    'min_salary',
    'max_salary'
]

text_features = [
    'title',
    'company_profile',
    'description',
    'requirements',
    'benefits'
]

cat_features = [
    'function',
    'industry',
    'required_education',
    'required_experience',
    'telecommuting',
    'has_company_logo',
    'has_questions',
    'employment_type',
    'location',
    'department'
]

target = 'fraudulent'

# %% [markdown]
# # NaN'ы
#
# Для категориальных фичей наны надо заменить на отдельные значения 'NaN', для численных делать этого не нужно, т.к. catboost умеет их обрабатывать

# %%
data[cat_features] = data[cat_features].fillna('NaN')

# %%
data[cat_features].isna().sum()
# Out:
# function               0
# industry               0
# required_education     0
# required_experience    0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# location               0
# department             0
# dtype: int64

# %% [markdown]
# # Создание фичей

# %% [markdown]
# Численных фичей немного и обрабатывать их не нжуно, потому что мы будем использовать catboost. Для решающих деревьев нормировать признаки не нужно.
#
# Категориальные фичи лучше всего кодировать с помощью target_encoding, который уже реализован в catboost'е, так что их тоже обрабатывать дополнительно не нужно. Можно было бы исправить опечатки, если они есть, но это сложно и скорее всего опечатки тоже несут свою информацию, так что лучше их оставить.
#
# Текстовые фичи можно обработать по-разному, я думаю, что лучше всего использовать Tf-Idf, потому что сделать что-то более сложное не получится из-за малого количества данных. Другой вариант - использовать Bag of embeddings, но это чуть сложнее и стоит сначала посмотреть на качество, которое дает более простой вариант. Текст лучше всего объединить в одно поле.

# %%
# Чтобы слова не склеивались при взятии суммы строк
data[text_features] += ' '
data['text_merged'] = data[text_features].fillna('NaN').sum(axis=1)

# %% [markdown]
# Так как сейчас мы начнем применять трансформации, которые задействуют весь датасет, а не отдельные строчки, то нужно сделать деление на train/test, чтобы не было data leak.

# %%
data_train, data_test = train_test_split(data, test_size=0.3)

# %%
data_train.reset_index(inplace=True)
data_test.reset_index(inplace=True)

# %% [markdown]
# Теперь продолжим обрабатывать датасет

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 2), max_features=100)
tfidf.fit(data_train['text_merged'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=100,
#                 min_df=1, ngram_range=(1, 2), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
tfidf_column_names = sorted(tfidf.vocabulary_.keys(), key=lambda word: tfidf.vocabulary_[word])

# %%
data_train_text = pd.DataFrame(data=tfidf.transform(data_train['text_merged']).todense(), 
                               columns=tfidf_column_names)
data_test_text = pd.DataFrame(data=tfidf.transform(data_test['text_merged']).todense(), 
                              columns=tfidf_column_names)

# %%
data_train_merged = pd.concat([data_train ,data_train_text], axis=1)
data_test_merged = pd.concat([data_test ,data_test_text], axis=1)

# %%
data_train_merged
# Out:
#        index  job_id                                              title  \
# 0       6327    6328  Graduates: English Teacher Abroad (Conversatio...
# 1      10522   10523                  Account Executive - Inside Sales
# 2      10159   10160                 Customer Service Representative
# 3      13967   13968                Senior JavaScript and C# Developer
# 4       6512    6513                                   Project Manager
# ...      ...     ...                                                ...
# 12511  14088   14089          Factory Integration Software Team Leader
# 12512   2081    2082                                 Sales Team Leader
# 12513   8226    8227                      Automotive Controls Engineer
# 12514   7512    7513           English Teacher Abroad (Conversational)
# 12515   8681    8682                        Marketing Assistant: Email
#
#                              location        department  \
# 0            US, KY, Highland Heights               NaN
# 1                US, PA, Philadelphia               NaN
# 2                      CA, ON, London  Schools/Charters
# 3                     NZ, N, Auckland       Development
# 4                      US, TX, Dallas               NaN
# ...                               ...               ...
# 12511                          NL, ,                NaN
# 12512  PH, 40, Cavite or Alabang area             Sales
# 12513             US, MN, Minneapolis               NaN
# 12514                   US, CA, Chico               NaN
# 12515                       GB, LND,          Marketing
#
#                                          company_profile  \
# 0      We help teachers get safe &amp; secure jobs ab...
# 1      Founded in 2009 by early LinkedIn employees, P...
# 2      Voyageur is one of Ontario's leading transport...
# 3      HSAGlobal specialises in solutions enabling co...
# 4                                                    NaN
# ...                                                  ...
# 12511  ClarusApex is an international recruiting comp...
# 12512  If working in a cubical seems like your idea o...
# 12513  We Provide Full Time Permanent Positions for m...
# 12514  We help teachers get safe &amp; secure jobs ab...
# 12515  The Beans Group is a media company that exists...
#
#                                              description  \
# 0      Play with kids, get paid for it :-)Love travel...
# 1      PeopleLinx is recruiting someone who is enthus...
# 2      Together we’re going places!  Voyageur Transpo...
# 3      HSAGlobal are a New Zealand based business spe...
# 4      Yes, this is a commission job in which you hav...
# ...                                                  ...
# 12511  Is software development your passion and would...
# 12512  If working in a cubical seems like your idea o...
# 12513  (We have more than 1500+ Job openings in our w...
# 12514  Play with kids, get paid for it.Vacancies in A...
# 12515  Award-Winning London-Based Media Company are h...
#
#                                             requirements  \
# 0      University degree required. TEFL / TESOL / CEL...
# 1      Bachelor’s degree and 2+ years of SaaS sales a...
# 2      Candidates should ideally demonstrate the foll...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12511  Requirements:MSc, PDEng or PhD in computer sci...
# 12512                                                NaN
# 12513                                                NaN
# 12514  University degree required. TEFL / TESOL / CEL...
# 12515  Strong attention to detailA good university de...
#
#                                                 benefits  telecommuting  ...  \
# 0                                   See job description               0  ...
# 1      Competitive compensation with uncapped commiss...              0  ...
# 2      Voyageur prides itself on its family-run tradi...              0  ...
# 3                                                    NaN              0  ...
# 4                                                    NaN              0  ...
# ...                                                  ...            ...  ...
# 12511                                                NaN              0  ...
# 12512  What's in it for you?We are not a call center....              0  ...
# 12513                                                NaN              0  ...
# 12514                               See job description               0  ...
# 12515  Life at The Beans GroupThere are many things t...              0  ...
#
#         will be      with  with the      work   working     world     years  \
# 0      0.000000  0.144153  0.000000  0.000000  0.000000  0.000000  0.000000
# 1      0.039246  0.199013  0.040363  0.054611  0.036235  0.046151  0.069673
# 2      0.000000  0.101869  0.000000  0.041930  0.000000  0.000000  0.053495
# 3      0.082978  0.093507  0.042670  0.028866  0.114920  0.048789  0.036828
# 4      0.000000  0.035250  0.000000  0.087057  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 12511  0.000000  0.140817  0.028560  0.057962  0.025639  0.032655  0.049299
# 12512  0.086299  0.064833  0.000000  0.020014  0.053120  0.101484  0.000000
# 12513  0.000000  0.059126  0.000000  0.073011  0.000000  0.000000  0.093148
# 12514  0.000000  0.162647  0.000000  0.000000  0.000000  0.000000  0.000000
# 12515  0.068581  0.115924  0.000000  0.119290  0.063321  0.040324  0.000000
#
#             you  you will      your
# 0      0.000000  0.000000  0.000000
# 1      0.087978  0.044207  0.103906
# 2      0.000000  0.000000  0.000000
# 3      0.248020  0.140204  0.000000
# 4      0.233747  0.070472  0.000000
# ...         ...       ...       ...
# 12511  0.145253  0.031280  0.049014
# 12512  0.386920  0.097210  0.152323
# 12513  0.156828  0.118205  0.000000
# 12514  0.000000  0.000000  0.000000
# 12515  0.333105  0.077252  0.000000
#
# [12516 rows x 121 columns]

# %% [markdown]
# # Обучение
#
# Теперь все готово и мы можем обучить catboost

# %% [markdown]
# Так как датасет несбалансированный, то в качестве метрики для моделей лучше всего использовать ROC-AUC. Порог, по которому мы сможем определять, плохая ли вакансия, можно будет установить позже, выбрав precision/recall tradeoff, который нас устроит.

# %%
cat = CatBoostClassifier(2000, cat_features=cat_features, eval_metric='AUC')
val_ds = Pool(data_test_merged[tfidf_column_names + cat_features + num_features], 
              data_test_merged[target], 
              cat_features=cat_features)
train_ds = Pool(data_train_merged[tfidf_column_names + cat_features + num_features], 
                data_train_merged[target],
                cat_features=cat_features)

# %%
cat.fit(train_ds, eval_set=val_ds)
# Out:
# Learning rate set to 0.043756
# 0:	test: 0.8126803	best: 0.8126803 (0)	total: 86.3ms	remaining: 2m 52s
# 1:	test: 0.8470429	best: 0.8470429 (1)	total: 123ms	remaining: 2m 2s
# 2:	test: 0.8448674	best: 0.8470429 (1)	total: 150ms	remaining: 1m 39s
# 3:	test: 0.8617430	best: 0.8617430 (3)	total: 175ms	remaining: 1m 27s
# 4:	test: 0.8641925	best: 0.8641925 (4)	total: 207ms	remaining: 1m 22s
# 5:	test: 0.8625717	best: 0.8641925 (4)	total: 237ms	remaining: 1m 18s
# 6:	test: 0.8619318	best: 0.8641925 (4)	total: 270ms	remaining: 1m 16s
# 7:	test: 0.8713644	best: 0.8713644 (7)	total: 302ms	remaining: 1m 15s
# 8:	test: 0.8730449	best: 0.8730449 (8)	total: 322ms	remaining: 1m 11s
# 9:	test: 0.8746719	best: 0.8746719 (9)	total: 347ms	remaining: 1m 9s
# 10:	test: 0.8765557	best: 0.8765557 (10)	total: 372ms	remaining: 1m 7s
# 11:	test: 0.8844267	best: 0.8844267 (11)	total: 397ms	remaining: 1m 5s
# 12:	test: 0.8897695	best: 0.8897695 (12)	total: 430ms	remaining: 1m 5s
# 13:	test: 0.8961517	best: 0.8961517 (13)	total: 458ms	remaining: 1m 4s
# 14:	test: 0.8979038	best: 0.8979038 (14)	total: 482ms	remaining: 1m 3s
# 15:	test: 0.8982132	best: 0.8982132 (15)	total: 506ms	remaining: 1m 2s
# 16:	test: 0.9001662	best: 0.9001662 (16)	total: 531ms	remaining: 1m 1s
# 17:	test: 0.8998477	best: 0.9001662 (16)	total: 556ms	remaining: 1m 1s
# 18:	test: 0.8999563	best: 0.9001662 (16)	total: 581ms	remaining: 1m
# 19:	test: 0.9075071	best: 0.9075071 (19)	total: 607ms	remaining: 1m
# 20:	test: 0.9145893	best: 0.9145893 (20)	total: 642ms	remaining: 1m
# 21:	test: 0.9194292	best: 0.9194292 (21)	total: 672ms	remaining: 1m
# 22:	test: 0.9204777	best: 0.9204777 (22)	total: 698ms	remaining: 60s
# 23:	test: 0.9208916	best: 0.9208916 (23)	total: 721ms	remaining: 59.3s
# 24:	test: 0.9213673	best: 0.9213673 (24)	total: 744ms	remaining: 58.8s
# 25:	test: 0.9217599	best: 0.9217599 (25)	total: 769ms	remaining: 58.4s
# 26:	test: 0.9237169	best: 0.9237169 (26)	total: 797ms	remaining: 58.2s
# 27:	test: 0.9336593	best: 0.9336593 (27)	total: 820ms	remaining: 57.7s
# 28:	test: 0.9400563	best: 0.9400563 (28)	total: 847ms	remaining: 57.5s
# 29:	test: 0.9433573	best: 0.9433573 (29)	total: 883ms	remaining: 58s
# 30:	test: 0.9497749	best: 0.9497749 (30)	total: 919ms	remaining: 58.4s
# 31:	test: 0.9540338	best: 0.9540338 (31)	total: 943ms	remaining: 58s
# 32:	test: 0.9563027	best: 0.9563027 (32)	total: 964ms	remaining: 57.5s
# 33:	test: 0.9574570	best: 0.9574570 (33)	total: 986ms	remaining: 57s
# 34:	test: 0.9580289	best: 0.9580289 (34)	total: 1s	remaining: 56.5s
# 35:	test: 0.9583013	best: 0.9583013 (35)	total: 1.03s	remaining: 56.1s
# 36:	test: 0.9583194	best: 0.9583194 (36)	total: 1.05s	remaining: 56s
# 37:	test: 0.9598634	best: 0.9598634 (37)	total: 1.09s	remaining: 56.5s
# 38:	test: 0.9605472	best: 0.9605472 (38)	total: 1.12s	remaining: 56.2s
# 39:	test: 0.9608279	best: 0.9608279 (39)	total: 1.14s	remaining: 56s
# 40:	test: 0.9612986	best: 0.9612986 (40)	total: 1.17s	remaining: 55.7s
# 41:	test: 0.9614254	best: 0.9614254 (41)	total: 1.19s	remaining: 55.5s
# 42:	test: 0.9621710	best: 0.9621710 (42)	total: 1.21s	remaining: 55.2s
# 43:	test: 0.9622887	best: 0.9622887 (43)	total: 1.24s	remaining: 55.1s
# 44:	test: 0.9625627	best: 0.9625627 (44)	total: 1.27s	remaining: 55.1s
# 45:	test: 0.9626220	best: 0.9626220 (45)	total: 1.3s	remaining: 55.3s
# 46:	test: 0.9625117	best: 0.9626220 (45)	total: 1.35s	remaining: 56.1s
# 47:	test: 0.9626664	best: 0.9626664 (47)	total: 1.38s	remaining: 56.1s
# 48:	test: 0.9625561	best: 0.9626664 (47)	total: 1.41s	remaining: 56s
# 49:	test: 0.9627273	best: 0.9627273 (49)	total: 1.43s	remaining: 55.9s
# 50:	test: 0.9628722	best: 0.9628722 (50)	total: 1.46s	remaining: 55.8s
# 51:	test: 0.9633380	best: 0.9633380 (51)	total: 1.49s	remaining: 56s
# 52:	test: 0.9637972	best: 0.9637972 (52)	total: 1.53s	remaining: 56.1s
# 53:	test: 0.9641000	best: 0.9641000 (53)	total: 1.55s	remaining: 56s
# 54:	test: 0.9644975	best: 0.9644975 (54)	total: 1.58s	remaining: 55.9s
# 55:	test: 0.9645905	best: 0.9645905 (55)	total: 1.61s	remaining: 55.9s
# 56:	test: 0.9646572	best: 0.9646572 (56)	total: 1.64s	remaining: 55.8s
# 57:	test: 0.9648769	best: 0.9648769 (57)	total: 1.66s	remaining: 55.6s
# 58:	test: 0.9650934	best: 0.9650934 (58)	total: 1.69s	remaining: 55.4s
# 197:	test: 0.9760793	best: 0.9760793 (197)	total: 5.57s	remaining: 50.7s
# 198:	test: 0.9760867	best: 0.9760867 (198)	total: 5.6s	remaining: 50.7s
# 199:	test: 0.9761089	best: 0.9761089 (199)	total: 5.63s	remaining: 50.7s
# 200:	test: 0.9761303	best: 0.9761303 (200)	total: 5.68s	remaining: 50.9s
# 201:	test: 0.9762538	best: 0.9762538 (201)	total: 5.74s	remaining: 51.1s
# 202:	test: 0.9762793	best: 0.9762793 (202)	total: 5.81s	remaining: 51.5s
# 203:	test: 0.9762595	best: 0.9762793 (202)	total: 5.86s	remaining: 51.6s
# 204:	test: 0.9762818	best: 0.9762818 (204)	total: 5.9s	remaining: 51.7s
# 205:	test: 0.9763089	best: 0.9763089 (205)	total: 5.93s	remaining: 51.6s
# 206:	test: 0.9762801	best: 0.9763089 (205)	total: 5.96s	remaining: 51.7s
# 207:	test: 0.9762085	best: 0.9763089 (205)	total: 5.99s	remaining: 51.6s
# 208:	test: 0.9762209	best: 0.9763089 (205)	total: 6.02s	remaining: 51.6s
# 209:	test: 0.9762242	best: 0.9763089 (205)	total: 6.04s	remaining: 51.5s
# 210:	test: 0.9762982	best: 0.9763089 (205)	total: 6.07s	remaining: 51.5s
# 211:	test: 0.9763723	best: 0.9763723 (211)	total: 6.1s	remaining: 51.4s
# 212:	test: 0.9764974	best: 0.9764974 (212)	total: 6.13s	remaining: 51.4s
# 213:	test: 0.9765254	best: 0.9765254 (213)	total: 6.15s	remaining: 51.3s
# 214:	test: 0.9765509	best: 0.9765509 (214)	total: 6.18s	remaining: 51.3s
# 215:	test: 0.9765089	best: 0.9765509 (214)	total: 6.22s	remaining: 51.4s
# 216:	test: 0.9766900	best: 0.9766900 (216)	total: 6.26s	remaining: 51.4s
# 217:	test: 0.9766842	best: 0.9766900 (216)	total: 6.29s	remaining: 51.4s
# 218:	test: 0.9767319	best: 0.9767319 (218)	total: 6.31s	remaining: 51.3s
# 219:	test: 0.9767665	best: 0.9767665 (219)	total: 6.34s	remaining: 51.3s
# 220:	test: 0.9768266	best: 0.9768266 (220)	total: 6.36s	remaining: 51.2s
# 221:	test: 0.9768159	best: 0.9768266 (220)	total: 6.4s	remaining: 51.3s
# 222:	test: 0.9768702	best: 0.9768702 (222)	total: 6.43s	remaining: 51.2s
# 223:	test: 0.9768949	best: 0.9768949 (223)	total: 6.46s	remaining: 51.2s
# 224:	test: 0.9769196	best: 0.9769196 (224)	total: 6.48s	remaining: 51.1s
# 225:	test: 0.9769912	best: 0.9769912 (225)	total: 6.51s	remaining: 51.1s
# 226:	test: 0.9769714	best: 0.9769912 (225)	total: 6.53s	remaining: 51s
# 227:	test: 0.9770603	best: 0.9770603 (227)	total: 6.56s	remaining: 51s
# 228:	test: 0.9771722	best: 0.9771722 (228)	total: 6.61s	remaining: 51.1s
# 229:	test: 0.9771500	best: 0.9771722 (228)	total: 6.65s	remaining: 51.2s
# 230:	test: 0.9772595	best: 0.9772595 (230)	total: 6.67s	remaining: 51.1s
# 231:	test: 0.9770307	best: 0.9772595 (230)	total: 6.7s	remaining: 51.1s
# 232:	test: 0.9770266	best: 0.9772595 (230)	total: 6.73s	remaining: 51s
# 233:	test: 0.9770842	best: 0.9772595 (230)	total: 6.76s	remaining: 51s
# 234:	test: 0.9771146	best: 0.9772595 (230)	total: 6.78s	remaining: 50.9s
# 235:	test: 0.9771829	best: 0.9772595 (230)	total: 6.81s	remaining: 50.9s
# 236:	test: 0.9773418	best: 0.9773418 (236)	total: 6.85s	remaining: 51s
# 237:	test: 0.9773451	best: 0.9773451 (237)	total: 6.88s	remaining: 50.9s
# 238:	test: 0.9773368	best: 0.9773451 (237)	total: 6.9s	remaining: 50.9s
# 239:	test: 0.9773418	best: 0.9773451 (237)	total: 6.93s	remaining: 50.8s
# 240:	test: 0.9773804	best: 0.9773804 (240)	total: 6.96s	remaining: 50.8s
# 241:	test: 0.9773887	best: 0.9773887 (241)	total: 6.98s	remaining: 50.7s
# 242:	test: 0.9773739	best: 0.9773887 (241)	total: 7.01s	remaining: 50.7s
# 243:	test: 0.9772685	best: 0.9773887 (241)	total: 7.03s	remaining: 50.6s
# 244:	test: 0.9773195	best: 0.9773887 (241)	total: 7.07s	remaining: 50.6s
# 245:	test: 0.9774405	best: 0.9774405 (245)	total: 7.1s	remaining: 50.6s
# 246:	test: 0.9774669	best: 0.9774669 (246)	total: 7.12s	remaining: 50.5s
# 247:	test: 0.9775417	best: 0.9775417 (247)	total: 7.15s	remaining: 50.5s
# 248:	test: 0.9775261	best: 0.9775417 (247)	total: 7.17s	remaining: 50.4s
# 249:	test: 0.9775146	best: 0.9775417 (247)	total: 7.2s	remaining: 50.4s
# 250:	test: 0.9775903	best: 0.9775903 (250)	total: 7.23s	remaining: 50.4s
# 251:	test: 0.9777409	best: 0.9777409 (251)	total: 7.25s	remaining: 50.3s
# 252:	test: 0.9778174	best: 0.9778174 (252)	total: 7.28s	remaining: 50.3s
# 253:	test: 0.9778569	best: 0.9778569 (253)	total: 7.31s	remaining: 50.3s
# 254:	test: 0.9778602	best: 0.9778602 (254)	total: 7.34s	remaining: 50.2s
# 255:	test: 0.9778965	best: 0.9778965 (255)	total: 7.36s	remaining: 50.2s
# 256:	test: 0.9779310	best: 0.9779310 (256)	total: 7.39s	remaining: 50.1s
# 257:	test: 0.9778693	best: 0.9779310 (256)	total: 7.41s	remaining: 50.1s
# 258:	test: 0.9779631	best: 0.9779631 (258)	total: 7.44s	remaining: 50s
# 259:	test: 0.9780553	best: 0.9780553 (259)	total: 7.47s	remaining: 50s
# 260:	test: 0.9780709	best: 0.9780709 (260)	total: 7.5s	remaining: 50s
# 261:	test: 0.9780446	best: 0.9780709 (260)	total: 7.53s	remaining: 50s
# 262:	test: 0.9780734	best: 0.9780734 (262)	total: 7.56s	remaining: 49.9s
# 263:	test: 0.9780775	best: 0.9780775 (263)	total: 7.58s	remaining: 49.9s
# 264:	test: 0.9780536	best: 0.9780775 (263)	total: 7.61s	remaining: 49.8s
# 265:	test: 0.9780536	best: 0.9780775 (263)	total: 7.64s	remaining: 49.8s
# 335:	test: 0.9792692	best: 0.9793424 (334)	total: 9.76s	remaining: 48.4s
# 336:	test: 0.9792511	best: 0.9793424 (334)	total: 9.79s	remaining: 48.3s
# 337:	test: 0.9792338	best: 0.9793424 (334)	total: 9.82s	remaining: 48.3s
# 338:	test: 0.9792478	best: 0.9793424 (334)	total: 9.84s	remaining: 48.2s
# 339:	test: 0.9793260	best: 0.9793424 (334)	total: 9.87s	remaining: 48.2s
# 340:	test: 0.9793424	best: 0.9793424 (334)	total: 9.89s	remaining: 48.1s
# 341:	test: 0.9793679	best: 0.9793679 (341)	total: 9.93s	remaining: 48.1s
# 342:	test: 0.9793515	best: 0.9793679 (341)	total: 9.96s	remaining: 48.1s
# 343:	test: 0.9793778	best: 0.9793778 (343)	total: 9.99s	remaining: 48.1s
# 344:	test: 0.9794091	best: 0.9794091 (344)	total: 10s	remaining: 48.1s
# 345:	test: 0.9794535	best: 0.9794535 (345)	total: 10s	remaining: 48s
# 346:	test: 0.9794700	best: 0.9794700 (346)	total: 10.1s	remaining: 48s
# 347:	test: 0.9794725	best: 0.9794725 (347)	total: 10.1s	remaining: 47.9s
# 348:	test: 0.9794124	best: 0.9794725 (347)	total: 10.1s	remaining: 47.9s
# 349:	test: 0.9794247	best: 0.9794725 (347)	total: 10.2s	remaining: 47.9s
# 350:	test: 0.9794239	best: 0.9794725 (347)	total: 10.2s	remaining: 47.9s
# 351:	test: 0.9794700	best: 0.9794725 (347)	total: 10.2s	remaining: 47.8s
# 352:	test: 0.9795054	best: 0.9795054 (352)	total: 10.2s	remaining: 47.8s
# 353:	test: 0.9796041	best: 0.9796041 (353)	total: 10.3s	remaining: 47.8s
# 354:	test: 0.9796873	best: 0.9796873 (354)	total: 10.3s	remaining: 47.7s
# 355:	test: 0.9796980	best: 0.9796980 (355)	total: 10.3s	remaining: 47.7s
# 356:	test: 0.9796897	best: 0.9796980 (355)	total: 10.4s	remaining: 47.6s
# 357:	test: 0.9797029	best: 0.9797029 (357)	total: 10.4s	remaining: 47.6s
# 358:	test: 0.9797465	best: 0.9797465 (358)	total: 10.4s	remaining: 47.6s
# 359:	test: 0.9797539	best: 0.9797539 (359)	total: 10.4s	remaining: 47.6s
# 360:	test: 0.9797794	best: 0.9797794 (360)	total: 10.5s	remaining: 47.5s
# 361:	test: 0.9797358	best: 0.9797794 (360)	total: 10.5s	remaining: 47.5s
# 362:	test: 0.9797383	best: 0.9797794 (360)	total: 10.5s	remaining: 47.4s
# 363:	test: 0.9796856	best: 0.9797794 (360)	total: 10.5s	remaining: 47.4s
# 364:	test: 0.9797292	best: 0.9797794 (360)	total: 10.6s	remaining: 47.4s
# 365:	test: 0.9797119	best: 0.9797794 (360)	total: 10.6s	remaining: 47.4s
# 366:	test: 0.9797210	best: 0.9797794 (360)	total: 10.6s	remaining: 47.3s
# 367:	test: 0.9796815	best: 0.9797794 (360)	total: 10.7s	remaining: 47.3s
# 368:	test: 0.9796617	best: 0.9797794 (360)	total: 10.7s	remaining: 47.2s
# 369:	test: 0.9796436	best: 0.9797794 (360)	total: 10.7s	remaining: 47.2s
# 405:	test: 0.9800584	best: 0.9800650 (404)	total: 11.7s	remaining: 45.9s
# 406:	test: 0.9800601	best: 0.9800650 (404)	total: 11.7s	remaining: 45.9s
# 407:	test: 0.9800699	best: 0.9800699 (407)	total: 11.8s	remaining: 45.9s
# 408:	test: 0.9800683	best: 0.9800699 (407)	total: 11.8s	remaining: 45.9s
# 409:	test: 0.9800831	best: 0.9800831 (409)	total: 11.8s	remaining: 45.8s
# 410:	test: 0.9801350	best: 0.9801350 (410)	total: 11.8s	remaining: 45.8s
# 411:	test: 0.9801292	best: 0.9801350 (410)	total: 11.9s	remaining: 45.8s
# 412:	test: 0.9801234	best: 0.9801350 (410)	total: 11.9s	remaining: 45.7s
# 413:	test: 0.9801136	best: 0.9801350 (410)	total: 11.9s	remaining: 45.7s
# 414:	test: 0.9801317	best: 0.9801350 (410)	total: 12s	remaining: 45.7s
# 415:	test: 0.9801572	best: 0.9801572 (415)	total: 12s	remaining: 45.7s
# 416:	test: 0.9801448	best: 0.9801572 (415)	total: 12s	remaining: 45.6s
# 417:	test: 0.9801251	best: 0.9801572 (415)	total: 12.1s	remaining: 45.6s
# 418:	test: 0.9801350	best: 0.9801572 (415)	total: 12.1s	remaining: 45.6s
# 419:	test: 0.9800996	best: 0.9801572 (415)	total: 12.1s	remaining: 45.5s
# 420:	test: 0.9800963	best: 0.9801572 (415)	total: 12.1s	remaining: 45.5s
# 421:	test: 0.9800922	best: 0.9801572 (415)	total: 12.2s	remaining: 45.5s
# 422:	test: 0.9800485	best: 0.9801572 (415)	total: 12.2s	remaining: 45.5s
# 423:	test: 0.9801712	best: 0.9801712 (423)	total: 12.2s	remaining: 45.5s
# 424:	test: 0.9801893	best: 0.9801893 (424)	total: 12.3s	remaining: 45.4s
# 425:	test: 0.9802502	best: 0.9802502 (425)	total: 12.3s	remaining: 45.4s
# 426:	test: 0.9802773	best: 0.9802773 (426)	total: 12.3s	remaining: 45.4s
# 427:	test: 0.9802880	best: 0.9802880 (427)	total: 12.3s	remaining: 45.3s
# 428:	test: 0.9802930	best: 0.9802930 (428)	total: 12.4s	remaining: 45.3s
# 429:	test: 0.9803629	best: 0.9803629 (429)	total: 12.4s	remaining: 45.3s
# 430:	test: 0.9804074	best: 0.9804074 (430)	total: 12.4s	remaining: 45.3s
# 431:	test: 0.9804074	best: 0.9804074 (430)	total: 12.5s	remaining: 45.3s
# 432:	test: 0.9803818	best: 0.9804074 (430)	total: 12.5s	remaining: 45.3s
# 433:	test: 0.9803950	best: 0.9804074 (430)	total: 12.5s	remaining: 45.2s
# 434:	test: 0.9803909	best: 0.9804074 (430)	total: 12.6s	remaining: 45.2s
# 435:	test: 0.9803942	best: 0.9804074 (430)	total: 12.6s	remaining: 45.2s
# 436:	test: 0.9803744	best: 0.9804074 (430)	total: 12.6s	remaining: 45.1s
# 437:	test: 0.9803843	best: 0.9804074 (430)	total: 12.7s	remaining: 45.1s
# 438:	test: 0.9804082	best: 0.9804082 (438)	total: 12.7s	remaining: 45.1s
# 509:	test: 0.9814369	best: 0.9814369 (509)	total: 15s	remaining: 43.9s
# 510:	test: 0.9814509	best: 0.9814509 (510)	total: 15.1s	remaining: 43.9s
# 511:	test: 0.9814567	best: 0.9814567 (511)	total: 15.1s	remaining: 43.9s
# 512:	test: 0.9813159	best: 0.9814567 (511)	total: 15.1s	remaining: 43.9s
# 513:	test: 0.9813349	best: 0.9814567 (511)	total: 15.2s	remaining: 43.9s
# 514:	test: 0.9813381	best: 0.9814567 (511)	total: 15.2s	remaining: 43.9s
# 515:	test: 0.9813414	best: 0.9814567 (511)	total: 15.2s	remaining: 43.8s
# 516:	test: 0.9813464	best: 0.9814567 (511)	total: 15.3s	remaining: 43.8s
# 517:	test: 0.9813867	best: 0.9814567 (511)	total: 15.3s	remaining: 43.7s
# 518:	test: 0.9814460	best: 0.9814567 (511)	total: 15.3s	remaining: 43.7s
# 519:	test: 0.9814822	best: 0.9814822 (519)	total: 15.4s	remaining: 43.7s
# 520:	test: 0.9815299	best: 0.9815299 (520)	total: 15.4s	remaining: 43.7s
# 521:	test: 0.9815414	best: 0.9815414 (521)	total: 15.4s	remaining: 43.6s
# 522:	test: 0.9815398	best: 0.9815414 (521)	total: 15.4s	remaining: 43.6s
# 523:	test: 0.9815546	best: 0.9815546 (523)	total: 15.5s	remaining: 43.6s
# 524:	test: 0.9815768	best: 0.9815768 (524)	total: 15.5s	remaining: 43.5s
# 525:	test: 0.9815760	best: 0.9815768 (524)	total: 15.5s	remaining: 43.5s
# 526:	test: 0.9815941	best: 0.9815941 (526)	total: 15.6s	remaining: 43.5s
# 527:	test: 0.9815990	best: 0.9815990 (527)	total: 15.6s	remaining: 43.5s
# 528:	test: 0.9816533	best: 0.9816533 (528)	total: 15.6s	remaining: 43.4s
# 529:	test: 0.9816566	best: 0.9816566 (529)	total: 15.6s	remaining: 43.4s
# 530:	test: 0.9816221	best: 0.9816566 (529)	total: 15.7s	remaining: 43.3s
# 531:	test: 0.9816262	best: 0.9816566 (529)	total: 15.7s	remaining: 43.3s
# 532:	test: 0.9816402	best: 0.9816566 (529)	total: 15.7s	remaining: 43.2s
# 533:	test: 0.9816443	best: 0.9816566 (529)	total: 15.7s	remaining: 43.2s
# 534:	test: 0.9816344	best: 0.9816566 (529)	total: 15.8s	remaining: 43.2s
# 535:	test: 0.9817044	best: 0.9817044 (535)	total: 15.8s	remaining: 43.2s
# 536:	test: 0.9817159	best: 0.9817159 (536)	total: 15.8s	remaining: 43.1s
# 537:	test: 0.9817217	best: 0.9817217 (537)	total: 15.9s	remaining: 43.1s
# 538:	test: 0.9816608	best: 0.9817217 (537)	total: 15.9s	remaining: 43s
# 539:	test: 0.9817373	best: 0.9817373 (539)	total: 15.9s	remaining: 43s
# 540:	test: 0.9817373	best: 0.9817373 (539)	total: 15.9s	remaining: 43s
# 541:	test: 0.9817546	best: 0.9817546 (541)	total: 16s	remaining: 42.9s
# 542:	test: 0.9817809	best: 0.9817809 (542)	total: 16s	remaining: 42.9s
# 543:	test: 0.9817538	best: 0.9817809 (542)	total: 16s	remaining: 42.9s
# 544:	test: 0.9818007	best: 0.9818007 (544)	total: 16s	remaining: 42.8s
# 545:	test: 0.9818072	best: 0.9818072 (545)	total: 16.1s	remaining: 42.8s
# 546:	test: 0.9818212	best: 0.9818212 (546)	total: 16.1s	remaining: 42.8s
# 547:	test: 0.9818204	best: 0.9818212 (546)	total: 16.1s	remaining: 42.7s
# 548:	test: 0.9818147	best: 0.9818212 (546)	total: 16.1s	remaining: 42.7s
# 549:	test: 0.9817974	best: 0.9818212 (546)	total: 16.2s	remaining: 42.6s
# 550:	test: 0.9818064	best: 0.9818212 (546)	total: 16.2s	remaining: 42.6s
# 551:	test: 0.9818616	best: 0.9818616 (551)	total: 16.2s	remaining: 42.6s
# 552:	test: 0.9818780	best: 0.9818780 (552)	total: 16.3s	remaining: 42.6s
# 553:	test: 0.9818377	best: 0.9818780 (552)	total: 16.3s	remaining: 42.5s
# 554:	test: 0.9818426	best: 0.9818780 (552)	total: 16.3s	remaining: 42.5s
# 555:	test: 0.9819035	best: 0.9819035 (555)	total: 16.3s	remaining: 42.5s
# 556:	test: 0.9818723	best: 0.9819035 (555)	total: 16.4s	remaining: 42.4s
# 557:	test: 0.9818797	best: 0.9819035 (555)	total: 16.4s	remaining: 42.4s
# 558:	test: 0.9818912	best: 0.9819035 (555)	total: 16.4s	remaining: 42.4s
# 559:	test: 0.9818969	best: 0.9819035 (555)	total: 16.5s	remaining: 42.3s
# 560:	test: 0.9819430	best: 0.9819430 (560)	total: 16.5s	remaining: 42.3s
# 561:	test: 0.9819677	best: 0.9819677 (561)	total: 16.5s	remaining: 42.3s
# 562:	test: 0.9819867	best: 0.9819867 (562)	total: 16.5s	remaining: 42.2s
# 563:	test: 0.9819916	best: 0.9819916 (563)	total: 16.6s	remaining: 42.2s
# 564:	test: 0.9819587	best: 0.9819916 (563)	total: 16.6s	remaining: 42.1s
# 565:	test: 0.9819315	best: 0.9819916 (563)	total: 16.6s	remaining: 42.1s
# 566:	test: 0.9819258	best: 0.9819916 (563)	total: 16.6s	remaining: 42.1s
# 567:	test: 0.9819290	best: 0.9819916 (563)	total: 16.7s	remaining: 42.1s
# 568:	test: 0.9819323	best: 0.9819916 (563)	total: 16.7s	remaining: 42s
# 569:	test: 0.9821364	best: 0.9821364 (569)	total: 16.7s	remaining: 42s
# 570:	test: 0.9821537	best: 0.9821537 (570)	total: 16.8s	remaining: 41.9s
# 571:	test: 0.9821389	best: 0.9821537 (570)	total: 16.8s	remaining: 41.9s
# 572:	test: 0.9821447	best: 0.9821537 (570)	total: 16.8s	remaining: 41.9s
# 573:	test: 0.9821299	best: 0.9821537 (570)	total: 16.8s	remaining: 41.8s
# 574:	test: 0.9821175	best: 0.9821537 (570)	total: 16.9s	remaining: 41.8s
# 575:	test: 0.9821093	best: 0.9821537 (570)	total: 16.9s	remaining: 41.8s
# 576:	test: 0.9821266	best: 0.9821537 (570)	total: 16.9s	remaining: 41.8s
# 577:	test: 0.9822146	best: 0.9822146 (577)	total: 17s	remaining: 41.7s
# 578:	test: 0.9822237	best: 0.9822237 (578)	total: 17s	remaining: 41.7s
# 579:	test: 0.9822015	best: 0.9822237 (578)	total: 17s	remaining: 41.7s
# 580:	test: 0.9822146	best: 0.9822237 (578)	total: 17s	remaining: 41.6s
# 581:	test: 0.9821973	best: 0.9822237 (578)	total: 17.1s	remaining: 41.6s
# 582:	test: 0.9822270	best: 0.9822270 (582)	total: 17.1s	remaining: 41.6s
# 583:	test: 0.9822377	best: 0.9822377 (583)	total: 17.1s	remaining: 41.6s
# 584:	test: 0.9822113	best: 0.9822377 (583)	total: 17.2s	remaining: 41.5s
# 585:	test: 0.9822212	best: 0.9822377 (583)	total: 17.2s	remaining: 41.5s
# 586:	test: 0.9822031	best: 0.9822377 (583)	total: 17.2s	remaining: 41.5s
# 587:	test: 0.9822319	best: 0.9822377 (583)	total: 17.2s	remaining: 41.4s
# 588:	test: 0.9822401	best: 0.9822401 (588)	total: 17.3s	remaining: 41.4s
# 589:	test: 0.9822418	best: 0.9822418 (589)	total: 17.3s	remaining: 41.4s
# 590:	test: 0.9822607	best: 0.9822607 (590)	total: 17.3s	remaining: 41.3s
# 591:	test: 0.9822566	best: 0.9822607 (590)	total: 17.4s	remaining: 41.3s
# 592:	test: 0.9822698	best: 0.9822698 (592)	total: 17.4s	remaining: 41.3s
# 593:	test: 0.9822862	best: 0.9822862 (593)	total: 17.4s	remaining: 41.2s
# 594:	test: 0.9822986	best: 0.9822986 (594)	total: 17.4s	remaining: 41.2s
# 595:	test: 0.9822492	best: 0.9822986 (594)	total: 17.5s	remaining: 41.1s
# 596:	test: 0.9822525	best: 0.9822986 (594)	total: 17.5s	remaining: 41.1s
# 597:	test: 0.9822434	best: 0.9822986 (594)	total: 17.5s	remaining: 41.1s
# 598:	test: 0.9822467	best: 0.9822986 (594)	total: 17.6s	remaining: 41.1s
# 599:	test: 0.9821949	best: 0.9822986 (594)	total: 17.6s	remaining: 41s
# 600:	test: 0.9821833	best: 0.9822986 (594)	total: 17.6s	remaining: 41s
# 601:	test: 0.9821809	best: 0.9822986 (594)	total: 17.6s	remaining: 41s
# 602:	test: 0.9821817	best: 0.9822986 (594)	total: 17.7s	remaining: 40.9s
# 603:	test: 0.9822220	best: 0.9822986 (594)	total: 17.7s	remaining: 40.9s
# 604:	test: 0.9822319	best: 0.9822986 (594)	total: 17.7s	remaining: 40.8s
# 605:	test: 0.9822615	best: 0.9822986 (594)	total: 17.7s	remaining: 40.8s
# 606:	test: 0.9823019	best: 0.9823019 (606)	total: 17.8s	remaining: 40.8s
# 607:	test: 0.9822763	best: 0.9823019 (606)	total: 17.8s	remaining: 40.7s
# 608:	test: 0.9822870	best: 0.9823019 (606)	total: 17.8s	remaining: 40.7s
# 609:	test: 0.9823076	best: 0.9823076 (609)	total: 17.8s	remaining: 40.7s
# 610:	test: 0.9823084	best: 0.9823084 (610)	total: 17.9s	remaining: 40.6s
# 611:	test: 0.9823422	best: 0.9823422 (611)	total: 17.9s	remaining: 40.6s
# 612:	test: 0.9823414	best: 0.9823422 (611)	total: 17.9s	remaining: 40.5s
# 613:	test: 0.9823562	best: 0.9823562 (613)	total: 17.9s	remaining: 40.5s
# 614:	test: 0.9823504	best: 0.9823562 (613)	total: 18s	remaining: 40.5s
# 615:	test: 0.9823422	best: 0.9823562 (613)	total: 18s	remaining: 40.5s
# 616:	test: 0.9823463	best: 0.9823562 (613)	total: 18s	remaining: 40.4s
# 617:	test: 0.9823644	best: 0.9823644 (617)	total: 18.1s	remaining: 40.4s
# 618:	test: 0.9823570	best: 0.9823644 (617)	total: 18.1s	remaining: 40.3s
# 619:	test: 0.9823545	best: 0.9823644 (617)	total: 18.1s	remaining: 40.3s
# 620:	test: 0.9823455	best: 0.9823644 (617)	total: 18.1s	remaining: 40.3s
# 621:	test: 0.9823809	best: 0.9823809 (621)	total: 18.2s	remaining: 40.3s
# 622:	test: 0.9823726	best: 0.9823809 (621)	total: 18.2s	remaining: 40.2s
# 623:	test: 0.9823759	best: 0.9823809 (621)	total: 18.2s	remaining: 40.2s
# 624:	test: 0.9823776	best: 0.9823809 (621)	total: 18.3s	remaining: 40.2s
# 625:	test: 0.9823660	best: 0.9823809 (621)	total: 18.3s	remaining: 40.1s
# 626:	test: 0.9823669	best: 0.9823809 (621)	total: 18.3s	remaining: 40.1s
# 627:	test: 0.9823628	best: 0.9823809 (621)	total: 18.3s	remaining: 40.1s
# 628:	test: 0.9823710	best: 0.9823809 (621)	total: 18.4s	remaining: 40s
# 629:	test: 0.9823339	best: 0.9823809 (621)	total: 18.4s	remaining: 40s
# 630:	test: 0.9823290	best: 0.9823809 (621)	total: 18.4s	remaining: 40s
# 631:	test: 0.9823290	best: 0.9823809 (621)	total: 18.5s	remaining: 39.9s
# 632:	test: 0.9823438	best: 0.9823809 (621)	total: 18.5s	remaining: 39.9s
# 633:	test: 0.9823496	best: 0.9823809 (621)	total: 18.5s	remaining: 39.9s
# 634:	test: 0.9823990	best: 0.9823990 (634)	total: 18.5s	remaining: 39.9s
# 635:	test: 0.9823652	best: 0.9823990 (634)	total: 18.6s	remaining: 39.8s
# 636:	test: 0.9824245	best: 0.9824245 (636)	total: 18.6s	remaining: 39.8s
# 637:	test: 0.9824204	best: 0.9824245 (636)	total: 18.6s	remaining: 39.8s
# 638:	test: 0.9824047	best: 0.9824245 (636)	total: 18.7s	remaining: 39.7s
# 639:	test: 0.9823652	best: 0.9824245 (636)	total: 18.7s	remaining: 39.7s
# 640:	test: 0.9823743	best: 0.9824245 (636)	total: 18.7s	remaining: 39.7s
# 641:	test: 0.9824047	best: 0.9824245 (636)	total: 18.7s	remaining: 39.6s
# 642:	test: 0.9823866	best: 0.9824245 (636)	total: 18.8s	remaining: 39.6s
# 643:	test: 0.9823825	best: 0.9824245 (636)	total: 18.8s	remaining: 39.6s
# 644:	test: 0.9823924	best: 0.9824245 (636)	total: 18.8s	remaining: 39.5s
# 645:	test: 0.9823660	best: 0.9824245 (636)	total: 18.9s	remaining: 39.5s
# 646:	test: 0.9823471	best: 0.9824245 (636)	total: 18.9s	remaining: 39.5s
# 647:	test: 0.9823800	best: 0.9824245 (636)	total: 18.9s	remaining: 39.4s
# 648:	test: 0.9823866	best: 0.9824245 (636)	total: 18.9s	remaining: 39.4s
# 649:	test: 0.9823570	best: 0.9824245 (636)	total: 18.9s	remaining: 39.4s
# 650:	test: 0.9823405	best: 0.9824245 (636)	total: 19s	remaining: 39.3s
# 651:	test: 0.9823389	best: 0.9824245 (636)	total: 19s	remaining: 39.3s
# 652:	test: 0.9823356	best: 0.9824245 (636)	total: 19s	remaining: 39.2s
# 653:	test: 0.9823463	best: 0.9824245 (636)	total: 19.1s	remaining: 39.2s
# 654:	test: 0.9823356	best: 0.9824245 (636)	total: 19.1s	remaining: 39.2s
# 655:	test: 0.9823348	best: 0.9824245 (636)	total: 19.1s	remaining: 39.2s
# 656:	test: 0.9823364	best: 0.9824245 (636)	total: 19.1s	remaining: 39.1s
# 657:	test: 0.9823438	best: 0.9824245 (636)	total: 19.2s	remaining: 39.1s
# 658:	test: 0.9822689	best: 0.9824245 (636)	total: 19.2s	remaining: 39.1s
# 659:	test: 0.9822632	best: 0.9824245 (636)	total: 19.2s	remaining: 39s
# 660:	test: 0.9822656	best: 0.9824245 (636)	total: 19.3s	remaining: 39s
# 661:	test: 0.9822500	best: 0.9824245 (636)	total: 19.3s	remaining: 39s
# 662:	test: 0.9822393	best: 0.9824245 (636)	total: 19.3s	remaining: 38.9s
# ...
# 1787:	test: 0.9820558	best: 0.9830458 (1018)	total: 58.5s	remaining: 6.93s
# 1788:	test: 0.9820690	best: 0.9830458 (1018)	total: 58.5s	remaining: 6.9s
# 1789:	test: 0.9820591	best: 0.9830458 (1018)	total: 58.5s	remaining: 6.87s
# 1790:	test: 0.9820410	best: 0.9830458 (1018)	total: 58.5s	remaining: 6.83s
# 1791:	test: 0.9820443	best: 0.9830458 (1018)	total: 58.6s	remaining: 6.8s
# 1792:	test: 0.9820336	best: 0.9830458 (1018)	total: 58.6s	remaining: 6.76s
# 1793:	test: 0.9820360	best: 0.9830458 (1018)	total: 58.6s	remaining: 6.73s
# 1794:	test: 0.9820253	best: 0.9830458 (1018)	total: 58.6s	remaining: 6.7s
# 1795:	test: 0.9820352	best: 0.9830458 (1018)	total: 58.7s	remaining: 6.66s
# 1796:	test: 0.9819998	best: 0.9830458 (1018)	total: 58.7s	remaining: 6.63s
# 1797:	test: 0.9820006	best: 0.9830458 (1018)	total: 58.7s	remaining: 6.6s
# 1798:	test: 0.9819957	best: 0.9830458 (1018)	total: 58.7s	remaining: 6.56s
# 1799:	test: 0.9819957	best: 0.9830458 (1018)	total: 58.8s	remaining: 6.53s
# 1800:	test: 0.9820039	best: 0.9830458 (1018)	total: 58.8s	remaining: 6.5s
# 1801:	test: 0.9819685	best: 0.9830458 (1018)	total: 58.8s	remaining: 6.46s
# 1802:	test: 0.9820204	best: 0.9830458 (1018)	total: 58.8s	remaining: 6.43s
# 1803:	test: 0.9820163	best: 0.9830458 (1018)	total: 58.9s	remaining: 6.4s
# 1804:	test: 0.9820006	best: 0.9830458 (1018)	total: 58.9s	remaining: 6.36s
# 1805:	test: 0.9820097	best: 0.9830458 (1018)	total: 58.9s	remaining: 6.33s
# 1806:	test: 0.9820072	best: 0.9830458 (1018)	total: 58.9s	remaining: 6.29s
# 1807:	test: 0.9819883	best: 0.9830458 (1018)	total: 59s	remaining: 6.26s
# 1808:	test: 0.9820204	best: 0.9830458 (1018)	total: 59s	remaining: 6.23s
# 1809:	test: 0.9820081	best: 0.9830458 (1018)	total: 59s	remaining: 6.2s
# 1810:	test: 0.9820122	best: 0.9830458 (1018)	total: 59s	remaining: 6.16s
# 1811:	test: 0.9820270	best: 0.9830458 (1018)	total: 59.1s	remaining: 6.13s
# 1812:	test: 0.9820212	best: 0.9830458 (1018)	total: 59.1s	remaining: 6.1s
# 1813:	test: 0.9820212	best: 0.9830458 (1018)	total: 59.1s	remaining: 6.06s
# 1814:	test: 0.9819982	best: 0.9830458 (1018)	total: 59.2s	remaining: 6.03s
# 1815:	test: 0.9819850	best: 0.9830458 (1018)	total: 59.2s	remaining: 6s
# 1816:	test: 0.9819702	best: 0.9830458 (1018)	total: 59.2s	remaining: 5.97s
# 1817:	test: 0.9819792	best: 0.9830458 (1018)	total: 59.3s	remaining: 5.93s
# 1818:	test: 0.9819554	best: 0.9830458 (1018)	total: 59.3s	remaining: 5.9s
# 1819:	test: 0.9819743	best: 0.9830458 (1018)	total: 59.3s	remaining: 5.87s
# 1820:	test: 0.9819834	best: 0.9830458 (1018)	total: 59.4s	remaining: 5.84s
# 1821:	test: 0.9819727	best: 0.9830458 (1018)	total: 59.4s	remaining: 5.8s
# 1822:	test: 0.9819891	best: 0.9830458 (1018)	total: 59.5s	remaining: 5.77s
# 1823:	test: 0.9819891	best: 0.9830458 (1018)	total: 59.5s	remaining: 5.74s
# 1824:	test: 0.9819727	best: 0.9830458 (1018)	total: 59.5s	remaining: 5.71s
# 1825:	test: 0.9819595	best: 0.9830458 (1018)	total: 59.6s	remaining: 5.67s
# 1826:	test: 0.9819183	best: 0.9830458 (1018)	total: 59.6s	remaining: 5.64s
# 1827:	test: 0.9819052	best: 0.9830458 (1018)	total: 59.6s	remaining: 5.61s
# 1828:	test: 0.9819109	best: 0.9830458 (1018)	total: 59.7s	remaining: 5.58s
# 1829:	test: 0.9818747	best: 0.9830458 (1018)	total: 59.7s	remaining: 5.55s
# 1830:	test: 0.9818657	best: 0.9830458 (1018)	total: 59.8s	remaining: 5.52s
# 1831:	test: 0.9819126	best: 0.9830458 (1018)	total: 59.8s	remaining: 5.49s
# 1832:	test: 0.9819118	best: 0.9830458 (1018)	total: 59.9s	remaining: 5.45s
# 1833:	test: 0.9819118	best: 0.9830458 (1018)	total: 59.9s	remaining: 5.42s
# 1834:	test: 0.9819044	best: 0.9830458 (1018)	total: 59.9s	remaining: 5.39s
# 1835:	test: 0.9819093	best: 0.9830458 (1018)	total: 60s	remaining: 5.36s
# 1836:	test: 0.9819175	best: 0.9830458 (1018)	total: 1m	remaining: 5.33s
# 1837:	test: 0.9819356	best: 0.9830458 (1018)	total: 1m	remaining: 5.3s
# 1838:	test: 0.9819134	best: 0.9830458 (1018)	total: 1m	remaining: 5.26s
# 1839:	test: 0.9819299	best: 0.9830458 (1018)	total: 1m	remaining: 5.23s
# 1840:	test: 0.9819126	best: 0.9830458 (1018)	total: 1m	remaining: 5.2s
# 1841:	test: 0.9819554	best: 0.9830458 (1018)	total: 1m	remaining: 5.17s
# 1842:	test: 0.9819529	best: 0.9830458 (1018)	total: 1m	remaining: 5.13s
# 1843:	test: 0.9819529	best: 0.9830458 (1018)	total: 1m	remaining: 5.1s
# 1844:	test: 0.9819488	best: 0.9830458 (1018)	total: 1m	remaining: 5.07s
# 1845:	test: 0.9819562	best: 0.9830458 (1018)	total: 1m	remaining: 5.04s
# 1846:	test: 0.9819677	best: 0.9830458 (1018)	total: 1m	remaining: 5.01s
# 1847:	test: 0.9819727	best: 0.9830458 (1018)	total: 1m	remaining: 4.97s
# 1848:	test: 0.9819685	best: 0.9830458 (1018)	total: 1m	remaining: 4.94s
# 1849:	test: 0.9819603	best: 0.9830458 (1018)	total: 1m	remaining: 4.91s
# 1850:	test: 0.9819595	best: 0.9830458 (1018)	total: 1m	remaining: 4.88s
# 1851:	test: 0.9819718	best: 0.9830458 (1018)	total: 1m	remaining: 4.85s
# 1852:	test: 0.9819751	best: 0.9830458 (1018)	total: 1m	remaining: 4.81s
# 1853:	test: 0.9819809	best: 0.9830458 (1018)	total: 1m	remaining: 4.79s
# 1854:	test: 0.9819957	best: 0.9830458 (1018)	total: 1m	remaining: 4.75s
# 1855:	test: 0.9820204	best: 0.9830458 (1018)	total: 1m	remaining: 4.72s
# 1856:	test: 0.9820171	best: 0.9830458 (1018)	total: 1m	remaining: 4.69s
# 1857:	test: 0.9820204	best: 0.9830458 (1018)	total: 1m	remaining: 4.65s
# 1858:	test: 0.9820187	best: 0.9830458 (1018)	total: 1m	remaining: 4.62s
# 1859:	test: 0.9820253	best: 0.9830458 (1018)	total: 1m	remaining: 4.59s
# 1860:	test: 0.9820311	best: 0.9830458 (1018)	total: 1m	remaining: 4.55s
# 1861:	test: 0.9820369	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.52s
# 1862:	test: 0.9820344	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.49s
# 1863:	test: 0.9820105	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.46s
# 1864:	test: 0.9820541	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.42s
# 1865:	test: 0.9820566	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.39s
# 1866:	test: 0.9820624	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.36s
# 1867:	test: 0.9820336	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.32s
# 1868:	test: 0.9820344	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.29s
# 1869:	test: 0.9820229	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.26s
# 1870:	test: 0.9820253	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.22s
# 1871:	test: 0.9820574	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.19s
# 1872:	test: 0.9820525	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.16s
# 1873:	test: 0.9820533	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.12s
# 1874:	test: 0.9820550	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.09s
# 1875:	test: 0.9820747	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.06s
# 1876:	test: 0.9820237	best: 0.9830458 (1018)	total: 1m 1s	remaining: 4.02s
# 1877:	test: 0.9820072	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.99s
# 1878:	test: 0.9819562	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.96s
# 1879:	test: 0.9819595	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.92s
# 1880:	test: 0.9819471	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.89s
# 1881:	test: 0.9819365	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.86s
# 1882:	test: 0.9819323	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.83s
# 1883:	test: 0.9819290	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.79s
# 1884:	test: 0.9819274	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.76s
# 1885:	test: 0.9818862	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.73s
# 1886:	test: 0.9818945	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.69s
# 1887:	test: 0.9818887	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.66s
# 1888:	test: 0.9818550	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.63s
# 1889:	test: 0.9818467	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.59s
# 1890:	test: 0.9818369	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.56s
# 1891:	test: 0.9818410	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.53s
# 1892:	test: 0.9817998	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.5s
# 1893:	test: 0.9817957	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.46s
# 1894:	test: 0.9817826	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.43s
# 1895:	test: 0.9817686	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.4s
# 1896:	test: 0.9817496	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.36s
# 1897:	test: 0.9817480	best: 0.9830458 (1018)	total: 1m 1s	remaining: 3.33s
# 1898:	test: 0.9817653	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.3s
# 1899:	test: 0.9817883	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.27s
# 1900:	test: 0.9817990	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.23s
# 1901:	test: 0.9817735	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.2s
# 1902:	test: 0.9817546	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.17s
# 1903:	test: 0.9817603	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.13s
# 1904:	test: 0.9817595	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.1s
# 1905:	test: 0.9817735	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.07s
# 1906:	test: 0.9817850	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3.04s
# 1907:	test: 0.9817743	best: 0.9830458 (1018)	total: 1m 2s	remaining: 3s
# 1908:	test: 0.9817636	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.97s
# 1909:	test: 0.9817908	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.94s
# 1910:	test: 0.9817957	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.9s
# 1911:	test: 0.9818155	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.87s
# 1912:	test: 0.9818072	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.84s
# 1913:	test: 0.9818097	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.81s
# 1914:	test: 0.9818048	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.77s
# 1915:	test: 0.9817965	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.74s
# 1916:	test: 0.9818031	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.71s
# 1917:	test: 0.9818114	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.67s
# 1918:	test: 0.9818147	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.64s
# 1919:	test: 0.9818221	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.61s
# 1920:	test: 0.9818147	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.58s
# 1921:	test: 0.9818089	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.54s
# 1922:	test: 0.9818040	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.51s
# 1923:	test: 0.9818048	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.48s
# 1924:	test: 0.9818188	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.44s
# 1925:	test: 0.9818229	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.41s
# 1926:	test: 0.9818229	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.38s
# 1927:	test: 0.9818410	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.35s
# 1928:	test: 0.9818360	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.31s
# 1929:	test: 0.9818500	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.28s
# 1930:	test: 0.9818253	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.25s
# 1931:	test: 0.9818179	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.21s
# 1932:	test: 0.9817998	best: 0.9830458 (1018)	total: 1m 2s	remaining: 2.18s
# 1933:	test: 0.9818048	best: 0.9830458 (1018)	total: 1m 3s	remaining: 2.15s
# 1934:	test: 0.9818040	best: 0.9830458 (1018)	total: 1m 3s	remaining: 2.12s
# 1935:	test: 0.9818048	best: 0.9830458 (1018)	total: 1m 3s	remaining: 2.08s
# 1936:	test: 0.9818072	best: 0.9830458 (1018)	total: 1m 3s	remaining: 2.05s
# 1937:	test: 0.9818105	best: 0.9830458 (1018)	total: 1m 3s	remaining: 2.02s
# 1938:	test: 0.9818245	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.99s
# 1939:	test: 0.9818031	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.95s
# 1940:	test: 0.9817974	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.92s
# 1941:	test: 0.9818105	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.89s
# 1942:	test: 0.9818147	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.85s
# 1943:	test: 0.9818171	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.82s
# 1944:	test: 0.9818081	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.79s
# 1945:	test: 0.9817858	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.76s
# 1946:	test: 0.9817858	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.72s
# 1947:	test: 0.9817990	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.69s
# 1948:	test: 0.9818081	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.66s
# 1949:	test: 0.9818147	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.63s
# 1950:	test: 0.9818138	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.59s
# 1951:	test: 0.9818196	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.56s
# 1952:	test: 0.9818262	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.53s
# 1953:	test: 0.9818097	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.5s
# 1954:	test: 0.9818352	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.46s
# 1955:	test: 0.9818064	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.43s
# 1956:	test: 0.9817710	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.4s
# 1957:	test: 0.9817562	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.36s
# 1958:	test: 0.9816887	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.33s
# 1959:	test: 0.9816896	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.3s
# 1960:	test: 0.9816945	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.27s
# 1961:	test: 0.9817101	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.24s
# 1962:	test: 0.9817019	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.2s
# 1963:	test: 0.9816896	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.17s
# 1964:	test: 0.9816846	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.14s
# 1965:	test: 0.9816945	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.1s
# 1966:	test: 0.9816920	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.07s
# 1967:	test: 0.9816854	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.04s
# 1968:	test: 0.9816698	best: 0.9830458 (1018)	total: 1m 3s	remaining: 1.01s
# 1969:	test: 0.9816665	best: 0.9830458 (1018)	total: 1m 3s	remaining: 974ms
# 1970:	test: 0.9816665	best: 0.9830458 (1018)	total: 1m 4s	remaining: 942ms
# 1971:	test: 0.9816624	best: 0.9830458 (1018)	total: 1m 4s	remaining: 909ms
# 1972:	test: 0.9816591	best: 0.9830458 (1018)	total: 1m 4s	remaining: 877ms
# 1973:	test: 0.9816624	best: 0.9830458 (1018)	total: 1m 4s	remaining: 844ms
# 1974:	test: 0.9817579	best: 0.9830458 (1018)	total: 1m 4s	remaining: 812ms
# 1975:	test: 0.9817521	best: 0.9830458 (1018)	total: 1m 4s	remaining: 779ms
# 1976:	test: 0.9817373	best: 0.9830458 (1018)	total: 1m 4s	remaining: 746ms
# 1977:	test: 0.9817587	best: 0.9830458 (1018)	total: 1m 4s	remaining: 714ms
# 1978:	test: 0.9817653	best: 0.9830458 (1018)	total: 1m 4s	remaining: 681ms
# 1979:	test: 0.9817192	best: 0.9830458 (1018)	total: 1m 4s	remaining: 649ms
# 1980:	test: 0.9817200	best: 0.9830458 (1018)	total: 1m 4s	remaining: 616ms
# 1981:	test: 0.9817208	best: 0.9830458 (1018)	total: 1m 4s	remaining: 584ms
# 1982:	test: 0.9817184	best: 0.9830458 (1018)	total: 1m 4s	remaining: 551ms
# 1983:	test: 0.9816616	best: 0.9830458 (1018)	total: 1m 4s	remaining: 519ms
# 1984:	test: 0.9816468	best: 0.9830458 (1018)	total: 1m 4s	remaining: 487ms
# 1985:	test: 0.9816550	best: 0.9830458 (1018)	total: 1m 4s	remaining: 454ms
# 1986:	test: 0.9816764	best: 0.9830458 (1018)	total: 1m 4s	remaining: 422ms
# 1987:	test: 0.9816780	best: 0.9830458 (1018)	total: 1m 4s	remaining: 389ms
# 1988:	test: 0.9816756	best: 0.9830458 (1018)	total: 1m 4s	remaining: 357ms
# 1989:	test: 0.9816912	best: 0.9830458 (1018)	total: 1m 4s	remaining: 324ms
# 1990:	test: 0.9816682	best: 0.9830458 (1018)	total: 1m 4s	remaining: 292ms
# 1991:	test: 0.9816599	best: 0.9830458 (1018)	total: 1m 4s	remaining: 259ms
# 1992:	test: 0.9816624	best: 0.9830458 (1018)	total: 1m 4s	remaining: 227ms
# 1993:	test: 0.9816649	best: 0.9830458 (1018)	total: 1m 4s	remaining: 194ms
# 1994:	test: 0.9816583	best: 0.9830458 (1018)	total: 1m 4s	remaining: 162ms
# 1995:	test: 0.9816435	best: 0.9830458 (1018)	total: 1m 4s	remaining: 130ms
# 1996:	test: 0.9816451	best: 0.9830458 (1018)	total: 1m 4s	remaining: 97.2ms
# 1997:	test: 0.9816410	best: 0.9830458 (1018)	total: 1m 4s	remaining: 64.8ms
# 1998:	test: 0.9816229	best: 0.9830458 (1018)	total: 1m 4s	remaining: 32.4ms
# 1999:	test: 0.9816295	best: 0.9830458 (1018)	total: 1m 4s	remaining: 0us
#
# bestTest = 0.9830458259
# bestIteration = 1018
#
# Shrink model to first 1019 iterations.
